# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from google.colab import drive
import tarfile
import os
from tqdm import tqdm

# Step 1: Mount Google Drive
drive.mount('/content/drive')

# Step 2: Specify the path to the .tar.gz file and output directory
tar_gz_path = '/content/drive/MyDrive/AIMusicGenerator/MedleyDB_Sample.tar.gz'  # Replace with your file path
output_directory = '/content/drive/MyDrive/AIMusicGenerator/MedleyDB/'  # Replace with your desired output directory

# Step 3: Create the output directory if it does not exist
os.makedirs(output_directory, exist_ok=True)

# Step 4: Extract the .tar.gz file with progress tracking
with tarfile.open(tar_gz_path, "r:gz") as tar:
    members = tar.getmembers()  # Get the list of files in the archive
    total_files = len(members)
    print(f"Total files to extract: {total_files}")

    # Use tqdm to show progress
    for member in tqdm(members, desc="Extracting files", unit="file"):
        tar.extract(member, path=output_directory)

print(f"Extraction completed. Files are in: {output_directory}")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Total files to extract: 118
# Extracting files: 100%|██████████| 118/118 [00:11<00:00, 10.58file/s]
# Extraction completed. Files are in: /content/drive/MyDrive/AIMusicGenerator/MedleyDB/

# %%
import os

def display_directory_structure(folder, indent=0):
    """
    Recursively display the directory structure of a given folder.
    """
    try:
        items = os.listdir(folder)
    except PermissionError:
        print(" " * indent + f"[Permission Denied] {folder}")
        return

    for item in items:
        item_path = os.path.join(folder, item)
        if os.path.isdir(item_path):
            print(" " * indent + f"[Dir] {item}")
            display_directory_structure(item_path, indent + 4)  # Increase indentation for subdirectories
        else:
            print(" " * indent + f"[File] {item}")

if __name__ == "__main__":
    # Path to the directory you want to inspect
    dataset_folder = "/content/drive/MyDrive/AIMusicGenerator/MedleyDB/"
    print(f"Directory structure for: {dataset_folder}\n")
    display_directory_structure(dataset_folder)
# Out:
# Directory structure for: /content/drive/MyDrive/AIMusicGenerator/MedleyDB/
#
# [File] ._MedleyDB_sample
# [Dir] MedleyDB_sample
#     [File] ._Annotations
#     [Dir] Annotations
#         [File] ._Instrument_Activations
#         [Dir] Instrument_Activations
#             [File] ._ACTIVATION_CONF
#             [Dir] ACTIVATION_CONF
#                 [File] ._LizNelson_Rainfall_ACTIVATION_CONF.lab
#                 [File] LizNelson_Rainfall_ACTIVATION_CONF.lab
#                 [File] ._Phoenix_ScotchMorris_ACTIVATION_CONF.lab
#                 [File] Phoenix_ScotchMorris_ACTIVATION_CONF.lab
#             [File] ._SOURCEID
#             [Dir] SOURCEID
#                 [File] ._LizNelson_Rainfall_SOURCEID.lab
#                 [File] LizNelson_Rainfall_SOURCEID.lab
#                 [File] ._Phoenix_ScotchMorris_SOURCEID.lab
#                 [File] Phoenix_ScotchMorris_SOURCEID.lab
#         [File] ._Melody_Annotations
#         [Dir] Melody_Annotations
#             [File] ._MELODY1
#             [Dir] MELODY1
#                 [File] ._LizNelson_Rainfall_MELODY1.csv
#                 [File] LizNelson_Rainfall_MELODY1.csv
#                 [File] ._Phoenix_ScotchMorris_MELODY1.csv
#                 [File] Phoenix_ScotchMorris_MELODY1.csv
#             [File] ._MELODY2
#             [Dir] MELODY2
#                 [File] ._LizNelson_Rainfall_MELODY2.csv
#                 [File] LizNelson_Rainfall_MELODY2.csv
#                 [File] ._Phoenix_ScotchMorris_MELODY2.csv
#                 [File] Phoenix_ScotchMorris_MELODY2.csv
#             [File] ._MELODY3
#             [Dir] MELODY3
#                 [File] ._LizNelson_Rainfall_MELODY3.csv
#                 [File] LizNelson_Rainfall_MELODY3.csv
#                 [File] ._Phoenix_ScotchMorris_MELODY3.csv
#                 [File] Phoenix_ScotchMorris_MELODY3.csv
#         [File] ._Pitch_Annotations
#         [Dir] Pitch_Annotations
#             [File] ._LizNelson_Rainfall_STEM_01.csv
#             [File] LizNelson_Rainfall_STEM_01.csv
#             [File] ._Phoenix_ScotchMorris_STEM_02.csv
#             [File] Phoenix_ScotchMorris_STEM_02.csv
#             [File] ._Phoenix_ScotchMorris_STEM_03.csv
#             [File] Phoenix_ScotchMorris_STEM_03.csv
#         [File] ._Stem_Intervals
#         [Dir] Stem_Intervals
#             [File] ._LizNelson_Rainfall_INTERVALS.txt
#             [File] LizNelson_Rainfall_INTERVALS.txt
#             [File] ._Phoenix_ScotchMorris_INTERVALS.txt
#             [File] Phoenix_ScotchMorris_INTERVALS.txt
#         [File] ._Stem_Rankings
#         [Dir] Stem_Rankings
#             [File] ._LizNelson_Rainfall_RANKING.txt
#             [File] LizNelson_Rainfall_RANKING.txt
#             [File] ._Phoenix_ScotchMorris_RANKING.txt
#             [File] Phoenix_ScotchMorris_RANKING.txt
#     [File] ._Audio
#     [Dir] Audio
#         [File] ._LizNelson_Rainfall
#         [Dir] LizNelson_Rainfall
#             [File] ._LizNelson_Rainfall_METADATA.yaml
#             [File] LizNelson_Rainfall_METADATA.yaml
#             [File] ._LizNelson_Rainfall_MIX.wav
#             [File] LizNelson_Rainfall_MIX.wav
#             [File] ._LizNelson_Rainfall_RAW
#             [Dir] LizNelson_Rainfall_RAW
#                 [File] ._LizNelson_Rainfall_RAW_01_01.wav
#                 [File] LizNelson_Rainfall_RAW_01_01.wav
#                 [File] ._LizNelson_Rainfall_RAW_02_01.wav
#                 [File] LizNelson_Rainfall_RAW_02_01.wav
#                 [File] ._LizNelson_Rainfall_RAW_03_01.wav
#                 [File] LizNelson_Rainfall_RAW_03_01.wav
#                 [File] ._LizNelson_Rainfall_RAW_04_01.wav
#                 [File] LizNelson_Rainfall_RAW_04_01.wav
#                 [File] ._LizNelson_Rainfall_RAW_05_01.wav
#                 [File] LizNelson_Rainfall_RAW_05_01.wav
#             [File] ._LizNelson_Rainfall_STEMS
#             [Dir] LizNelson_Rainfall_STEMS
#                 [File] ._LizNelson_Rainfall_STEM_01.wav
#                 [File] LizNelson_Rainfall_STEM_01.wav
#                 [File] ._LizNelson_Rainfall_STEM_02.wav
#                 [File] LizNelson_Rainfall_STEM_02.wav
#                 [File] ._LizNelson_Rainfall_STEM_03.wav
#                 [File] LizNelson_Rainfall_STEM_03.wav
#                 [File] ._LizNelson_Rainfall_STEM_04.wav
#                 [File] LizNelson_Rainfall_STEM_04.wav
#                 [File] ._LizNelson_Rainfall_STEM_05.wav
#                 [File] LizNelson_Rainfall_STEM_05.wav
#         [File] ._Phoenix_ScotchMorris
#         [Dir] Phoenix_ScotchMorris
#             [File] ._Phoenix_ScotchMorris_METADATA.yaml
#             [File] Phoenix_ScotchMorris_METADATA.yaml
#             [File] ._Phoenix_ScotchMorris_MIX.wav
#             [File] Phoenix_ScotchMorris_MIX.wav
#             [File] ._Phoenix_ScotchMorris_RAW
#             [Dir] Phoenix_ScotchMorris_RAW
#                 [File] ._Phoenix_ScotchMorris_RAW_01_01.wav
#                 [File] Phoenix_ScotchMorris_RAW_01_01.wav
#                 [File] ._Phoenix_ScotchMorris_RAW_02_01.wav
#                 [File] Phoenix_ScotchMorris_RAW_02_01.wav
#                 [File] ._Phoenix_ScotchMorris_RAW_03_01.wav
#                 [File] Phoenix_ScotchMorris_RAW_03_01.wav
#                 [File] ._Phoenix_ScotchMorris_RAW_04_01.wav
#                 [File] Phoenix_ScotchMorris_RAW_04_01.wav
#                 [File] ._Phoenix_ScotchMorris_RAW_04_02.wav
#                 [File] Phoenix_ScotchMorris_RAW_04_02.wav
#             [File] ._Phoenix_ScotchMorris_STEMS
#             [Dir] Phoenix_ScotchMorris_STEMS
#                 [File] ._Phoenix_ScotchMorris_STEM_01.wav
#                 [File] Phoenix_ScotchMorris_STEM_01.wav
#                 [File] ._Phoenix_ScotchMorris_STEM_02.wav
#                 [File] Phoenix_ScotchMorris_STEM_02.wav
#                 [File] ._Phoenix_ScotchMorris_STEM_03.wav
#                 [File] Phoenix_ScotchMorris_STEM_03.wav
#                 [File] ._Phoenix_ScotchMorris_STEM_04.wav
#                 [File] Phoenix_ScotchMorris_STEM_04.wav

# %%
# Step 1: Install Sinsy
# !pip install sinsy

# Step 2: Import necessary libraries
from sinsy import Sinsy
import os

# Step 3: Set up paths
sinsy_model_dir = "/content/sinsy_model"  # Directory to store Sinsy models
xml_file_path = "/content/sample_musicxml.xml"  # Path to your MusicXML file
output_wav_path = "/content/synthesized_song.wav"  # Path for the output audio file

# Step 4: Download Sinsy models (if not already available)
if not os.path.exists(sinsy_model_dir):
    # !wget -P /content https://sinsy.jp/download/sinsy_models.tar.gz
    # !tar -xzf /content/sinsy_models.tar.gz -C /content
    print("Sinsy models downloaded and extracted.")

# Step 5: Initialize Sinsy
sinsy = Sinsy()
sinsy.setLanguages("jpn", sinsy_model_dir)  # Set language and model directory

# Step 6: Process MusicXML file
if sinsy.loadScore(xml_file_path):
    sinsy.synthesize(output_wav_path)
    print(f"Synthesized audio saved to {output_wav_path}")
else:
    print("Failed to load MusicXML file.")

# Step 7: Play the generated audio
from IPython.display import Audio
Audio(output_wav_path)
